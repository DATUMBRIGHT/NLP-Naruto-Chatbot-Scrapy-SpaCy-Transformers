# %%
import pandas as pd
from textwrap3 import wrap

# %%
df = pd.read_csv('/Users/brighttenkorangofori/Desktop/naruto/data/transcript/naruto.csv')

# %%
df.head()
# Out:
#       name                                               line
# 0   Naruto   (Laughing) Give it up. (Shows the stone faces...
# 1  Hiruzen   (Turns away from his writing) I hope you’re n...
# 2    Ninja                                       Naseer Sabah
# 3    Ninja                        is the best person on earth
# 4   Naruto                                               muah

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/brighttenkorangofori/Desktop/naruto/chat_bot/chat_bot.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/Users/brighttenkorangofori/Desktop/naruto/chat_bot/chat_bot.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df['number of words'] = [len(line.split() for line in df['line'])]
#
# TypeError: object of type 'generator' has no len()

# %%
df.isnull().sum()
# Out:
# name    0
# line    0
# dtype: int64

# %%
#lets remove action
import re
pattern = re.compile(r'\(.*?\)')
df['line'] = df['line'].apply(lambda x: re.sub(pattern," ",x).strip())

# %%
df['words'] = [len(line.split()) for line in df['line']]

# %%
df.drop(columns=['number of words'],axis = 1)
# Out:
#         name                                               line  words
# 0     Naruto  Give it up.   You’re just bent, because you di...     25
# 1    Hiruzen  I hope you’re not bothering me with some trivi...     16
# 2      Ninja                                       Naseer Sabah      2
# 3      Ninja                        is the best person on earth      6
# 4     Naruto                                               muah      1
# ..       ...                                                ...    ...
# 158    Iruka  Congratulations. You graduate. Naruto’s standi...     27
# 159    Iruka                                               Huh?      1
# 160   Naruto                                      Iruka Sensei!      2
# 161    Iruka                                    Ah! That hurts!      3
# 162    Iruka  Naruto. This is only the beginning. The road g...     38
#
# [163 rows x 3 columns]

# %%
naruto_speeches = df[(df['name'] == 'Naruto') & (df['words'] > 2)]
naruto_speeches.iloc[]
# Out:
#        name                                               line  \
# 0    Naruto  Give it up.   You’re just bent, because you di...
# 6    Naruto  Where’d you come from, Iruka Sensei!? What are...
# 20   Naruto                                       Like I care.
# 24   Naruto                      Gotcha! That’s my Sexy Jutsu!
# 26   Naruto                                 This sucks. Loser.
# 28   Naruto  So what? It’s not like there’s anyone waiting ...
# 30   Naruto                      What do you want now, Sensei?
# 32   Naruto  Now that’s some serious motivation! I’ll have ...
# 36   Naruto  Course I do.   Everybody knows. They were the ...
# 38   Naruto  Cause I’m going to be greater than any of them...
# 40   Naruto  Uh-uh. I... want to try on your headband. Come...
# 42   Naruto                                 That is so uncool!
# 44   Naruto                       Ugh...! I want another bowl!
# 46   Naruto  Ugh! That’s my worst technique! Great. I’m nev...
# 47   Naruto  Alright. Get it together, Naruto. You can do t...
# 61   Naruto                             Then why? Why only me?
# 63   Naruto      But... This time I really wanted to graduate.
# 77   Naruto  Let’s see... The first one is... Multi-Shadow ...
# 86   Naruto  Got me already? Not bad. You’re quick, Sensei....
# 88   Naruto  Listen, Iruka Sensei! I’m going to show you th...
# 90   Naruto  Mizuki Sensei told me about it. Believe it.   ...
# 96   Naruto           Wait a minute...   What’s going on here?
# 106  Naruto  What is this decree? Why does everyone else kn...
# 111  Naruto                           No...!   No, no, no, no!
# 136  Naruto  So it’s true. Iruka Sensei never believed in m...
# 142  Naruto  If you ever lay a hand on my Sensei... I’ll ki...
# 144  Naruto  Take your best shot, fool. I’ll give it back t...
# 146  Naruto                                Shadow Clone Jutsu!
# 151  Naruto  Sorry. I kinda got carried away.   You okay, I...
# 156  Naruto                           Sensei? How much longer?
#
#      number of words  words
# 0                 25     25
# 6                 11     11
# 20                 3      3
# 24                 5      5
# 26                 3      3
# 28                12     12
# 30                 6      6
# 32                12     12
# 36                41     41
# 38                45     45
# 40                11     11
# 42                 4      4
# 44                 5      5
# 46                10     10
# 47                13     13
# 61                 5      5
# 63                 8      8
# 77                17     17
# 86                16     16
# 88                37     37
# 90                20     20
# 96                 7      7
# 106               11     11
# 111                5      5
# 136               18     18
# 142               12     12
# 144               14     14
# 146                3      3
# 151               10     10
# 156                4      4

# %%
naruto_speech_index = list(naruto_speeches.index)
naruto_pre_speech_index = [i-1 for i in naruto_speech_index if i>1]

# %%
naruto_speech_index
# Out:
# [0,
#  6,
#  20,
#  24,
#  26,
#  28,
#  30,
#  32,
#  36,
#  38,
#  40,
#  42,
#  44,
#  46,
#  47,
#  61,
#  63,
#  77,
#  86,
#  88,
#  90,
#  96,
#  106,
#  111,
#  136,
#  142,
#  144,
#  146,
#  151,
#  156]

# %%
naruto_speech_index.remove(0)

# %%
len(naruto_speech_index),len(naruto_pre_speech_index)
# Out:
# (29, 29)

# %%
for speach,question in zip(naruto_speech_index,naruto_pre_speech_index):
        print(speach,question)
# Out:
# 6 5
# 20 19
# 24 23
# 26 25
# 28 27
# 30 29
# 32 31
# 36 35
# 38 37
# 40 39
# 42 41
# 44 43
# 46 45
# 47 46
# 61 60
# 63 62
# 77 76
# 86 85
# 88 87
# 90 89
# 96 95
# 106 105
# 111 110
# 136 135
# 142 141
# 144 143
# 146 145
# 151 150
# 156 155

# %%
def preprocess_df(df):
    
    #remove actions
    pattern = re.compile(r'\(.*?\)')
    df['line'].apply(lambda x: re.sub(pattern," ",x).strip())
    
    #clean text
    df['line'] = (df['line']
    .apply(lambda x: x.replace('\n', " "))  # Replace newline characters with spaces
    .apply(lambda x: re.sub(r'[!@#$%^&*(){}|\\[\]]', '', x))  # Remove special characters
    .apply(lambda x: x.strip())  # Remove leading and trailing whitespace
    .apply(lambda x: x.lower()) ) # Convert to lowercase

    return df 



def get_prompts(df):
    naruto_speeches = df[(df['name'] == 'Naruto') & (df['words']>2)]
    naruto_speech_index = list(naruto_speeches.index)
    naruto_speech_index.remove(0)
    naruto_pre_speech_index = [i-1 for i in naruto_speech_index if i>1] 

    
    #generate prompt for any other person + naturo response
    prompts = []
    system_prompt = """"You are Naruto Chatbot.
    Every question answered should be Naruto tone.
    Use question answer conversation provided """
    for speech,question in zip(naruto_speech_index,naruto_pre_speech_index):
        speech = df.iloc[speech]['line']
        question = df.iloc[question]['line']
        prompt = system_prompt
        prompt += '\n'
        prompt += f'User: {question}'
        prompts.append(prompt)
        
        prompt += '\n'
        prompt += f'Naruto: {speech}' 
        prompts.append(prompt)

    return prompts

# %%
prompts = get_prompts(df)

# %%
print(prompts[0])
# Out:
# "You are Naruto Chatbot.
#     Every question answered should be Naruto tone.
#     Use question answer conversation provided
# User: Oh yeah, Naruto!?
# Naruto: Where’d you come from, Iruka Sensei!? What are you doing here?

# %%
pd.DataFrame(prompts,columns= ['Convo'])
# Out:
#                                                 Convo
# 0   "You are Naruto Chatbot.\n    Every question a...
# 1   "You are Naruto Chatbot.\n    Every question a...
# 2   "You are Naruto Chatbot.\n    Every question a...
# 3   "You are Naruto Chatbot.\n    Every question a...
# 4   "You are Naruto Chatbot.\n    Every question a...
# 5   "You are Naruto Chatbot.\n    Every question a...
# 6   "You are Naruto Chatbot.\n    Every question a...
# 7   "You are Naruto Chatbot.\n    Every question a...
# 8   "You are Naruto Chatbot.\n    Every question a...
# 9   "You are Naruto Chatbot.\n    Every question a...
# 10  "You are Naruto Chatbot.\n    Every question a...
# 11  "You are Naruto Chatbot.\n    Every question a...
# 12  "You are Naruto Chatbot.\n    Every question a...
# 13  "You are Naruto Chatbot.\n    Every question a...
# 14  "You are Naruto Chatbot.\n    Every question a...
# 15  "You are Naruto Chatbot.\n    Every question a...
# 16  "You are Naruto Chatbot.\n    Every question a...
# 17  "You are Naruto Chatbot.\n    Every question a...
# 18  "You are Naruto Chatbot.\n    Every question a...
# 19  "You are Naruto Chatbot.\n    Every question a...
# 20  "You are Naruto Chatbot.\n    Every question a...
# 21  "You are Naruto Chatbot.\n    Every question a...
# 22  "You are Naruto Chatbot.\n    Every question a...
# 23  "You are Naruto Chatbot.\n    Every question a...
# 24  "You are Naruto Chatbot.\n    Every question a...
# 25  "You are Naruto Chatbot.\n    Every question a...
# 26  "You are Naruto Chatbot.\n    Every question a...
# 27  "You are Naruto Chatbot.\n    Every question a...
# 28  "You are Naruto Chatbot.\n    Every question a...

# %%
from datasets import Dataset
# Out:
#   Cell In[204], line 3
#     Dataset.from
#             ^
# SyntaxError: invalid syntax

# %%
_
